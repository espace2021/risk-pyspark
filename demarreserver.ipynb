# %%
# !pip install fastapi

# %%
# !pip install uvicorn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.1 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# ...

# %%
# !uvicorn fastapiserver:app --host 0.0.0.0 --port 8000 --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/home/ubuntu']
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [17654] using StatReload
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/26 09:04:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/26 09:04:34 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# INFO:     Started server process [17656]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:38768 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38768 - "GET /openapi.json HTTP/1.1" 200 OK
# ...
